# %%
import pandas as pd
import numpy as np

#Import Machine Learning Libraries
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer


#Import the plotting libraries
import seaborn as sns
import matplotlib.pyplot as plt
import math

from scipy import sparse

from sklearn.metrics import confusion_matrix

from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import classification_report

# %%
index_array = np.load('index_array.npy')
not_encode = pd.read_feather('not_Encoded')

# %%
df_check = pd.read_feather('To_Ampute')
df_check = df_check.drop(['HBW',
 'HBD',
 'Non-HB',
 'Peak',
 'Off_peak',
 'Drive',
 'Other',
 'Passenger',
 'Transit',
 'Walk',
 'Bicycle',
 '(2.0, 3.0]_x',
 '(11.0, 16.0]',
 '(5.0, 6.0]',
 '(4.0, 5.0]',
 '(3.0, 4.0]_x',
 '(-0.001, 1.0]',
 '(1.0, 2.0]_x',
 '(16.0, 56.0]',
 '(6.0, 8.0]',
 '(8.0, 11.0]'], axis = 1)

# %%
def impute(df, index_array, solver):

    count_array = np.unique(index_array)
    train_encode = not_encode.copy()
    if solver == 'regress':
        train_data =  df.copy()

        train_encode = not_encode.copy()
        is_notNaN = train_data.isnull()
        row_not_NaN = is_notNaN.any(axis = 1)
        row_not_NaN = row_not_NaN.replace([False],'f')
        row_not_NaN = row_not_NaN.replace([True], False)
        row_not_NaN = row_not_NaN.replace(['f'],True)

        train_encode = train_encode[row_not_NaN]
        train_data = train_data.dropna(axis=0)

        test_data = df.copy()


        test_encode = not_encode.copy()

        x_imputed_df = df.copy()

        mean_imputer = SimpleImputer(strategy='most_frequent')


        x_imputed_df = mean_imputer.fit_transform(x_imputed_df)

        x_imputed_df = pd.DataFrame(data = x_imputed_df, columns = [j for j in test_data.columns])
    
    
    #print(train_data.shape)
    #print(x_imputed_df.shape)
    
        train_data = train_data.drop([train_data.columns[np.where(index_array == j)[0][-1]] for j in count_array], axis = 1)
        test_data = test_data.drop([test_data.columns[np.where(index_array == j)[0][-1]] for j in count_array], axis = 1)
        x_imputed_df = x_imputed_df.drop([x_imputed_df.columns[np.where(index_array == j)[0][-1]] for j in count_array], axis = 1)
        index_array2 = np.copy(index_array)
    
        for i in count_array:
            pop_index = np.where(index_array2 == i)[0][-1]
            index_array2 = np.delete(index_array2, pop_index)
    
    
    #c_report = np.array()
        for i in count_array:
            y_checkna = df[[df.columns[np.where(index_array2 == i)[0][x]] for x in range(len(np.where(index_array2 == i)[0]))]].copy()
            if y_checkna.isnull().sum().sum() != 0:
                #print(i)
                y_nEncode = train_encode[train_encode.columns[i]].copy()

                y_train = train_data[[train_data.columns[np.where(index_array2 == i)[0][x]] for x in range(len(np.where(index_array2 == i)[0][:]))]].copy()
                #print("Y_train",y_train.shape)
                x_train = train_data[[l for l in train_data.columns if l not in y_train.columns]].copy()
                #rint(x_train.shape)


                y_t = test_data[[test_data.columns[np.where(index_array2 == i)[0][x]] for x in range(len(np.where(index_array2 == i)[0][:]))]].copy()
                #print(y_t.shape)

                x_test =  x_imputed_df[[l for l in x_imputed_df.columns if l not in y_t.columns]].copy()
                #print(x_test.shape)

                y_test = test_encode[test_encode.columns[i]].copy()

                is_NaN = y_t.isnull()
                row_has_NaN = is_NaN.any(axis=1)


                x_test = x_test[row_has_NaN]
                y_test = y_test[row_has_NaN]

                #print(x_test)



                #print(x_test)

                regress(x_train, y_nEncode, x_test, y_test)
    elif solver == 'mode':
        df_mode_impute = df_50.copy()
        nd = mean_imp(df_mode_impute)
        df_mode_impute = pd.DataFrame(data=nd, columns=df_mode_impute.columns)
        print(nd)
        for i in count_array:
            if df_50[df_50.columns[i]].isnull().sum().sum() != 0:
                is_NaN = df_50[[df_50.columns[i]]].isnull()
                row_has_NaN = is_NaN.any(axis=1)
                t = df_mode_impute[row_has_NaN].copy()
                k = train_encode[row_has_NaN].copy()
                #print(t[df_mode_impute.columns[i]], k[train_encode.columns[i]])
                print(classification_report(k[train_encode.columns[i]], t[df_mode_impute.columns[i]], digits = 3))
                #print(confusion_matrix(train_encode[train_encode.columns[i]], df_mode_impute[df_mode_impute.columns[i]]))

# %%
df.shape
# Out:
# (34608, 73)

# %%
def regress(x_train, y_nEncode, x_test, y_test):
    model = LogisticRegression(random_state=0, solver='lbfgs', multi_class='ovr', n_jobs=-1, max_iter=800, class_weight= 'balanced')

    model.fit(X = x_train, y = y_nEncode)
    y_predict = model.predict(x_test)
    print(classification_report(y_test, y_predict, digits = 3))
    print(confusion_matrix(y_test, y_predict))
#return y_train, x_train, y_test, x_test, y_predict

# %%
impute(df_arr[-1].copy(), index_array, 'regress')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                 precision    recall  f1-score   support
#
# (10.999, 19.0]      1.000     0.076     0.141        92
#   (19.0, 28.0]      0.000     0.000     0.000        77
#   (28.0, 35.0]      0.000     0.000     0.000        98
#   (35.0, 41.0]      0.000     0.000     0.000        86
#   (41.0, 47.0]      0.067     0.359     0.113        64
#   (47.0, 53.0]      0.073     0.479     0.127        73
#   (53.0, 58.0]      0.000     0.000     0.000        78
#   (58.0, 65.0]      0.000     0.000     0.000        96
#   (65.0, 72.0]      0.000     0.000     0.000        73
#   (72.0, 99.0]      0.000     0.000     0.000        89
#
#       accuracy                          0.079       826
#      macro avg      0.114     0.091     0.038       826
#   weighted avg      0.123     0.079     0.036       826
#
# [[ 7  0  0  0 29 56  0  0  0  0]
#  [ 0  0  0  0 30 47  0  0  0  0]
#  [ 0  0  0  0 40 58  0  0  0  0]
#  [ 0  0  0  0 46 40  0  0  0  0]
#  [ 0  0  0  0 23 41  0  0  0  0]
#  [ 0  0  0  0 38 35  0  0  0  0]
#  [ 0  0  0  0 29 49  0  0  0  0]
#  [ 0  0  0  0 43 53  0  0  0  0]
#  [ 0  0  0  0 34 39  0  0  0  0]
#  [ 0  0  0  0 30 59  0  0  0  0]]
#               precision    recall  f1-score   support
#
#            F      0.593     0.120     0.200       424
#            M      0.496     0.913     0.643       402
#
#     accuracy                          0.506       826
#    macro avg      0.544     0.517     0.421       826
# weighted avg      0.546     0.506     0.415       826
#
# [[ 51 373]
#  [ 35 367]]
#               precision    recall  f1-score   support
#
#            N      0.600     0.112     0.189       107
#            Y      0.907     0.991     0.947       931
#
#     accuracy                          0.901      1038
#    macro avg      0.753     0.552     0.568      1038
# weighted avg      0.875     0.901     0.869      1038
#
# [[ 12  95]
#  [  8 923]]
#               precision    recall  f1-score   support
#
#            N      0.963     0.946     0.955      1135
# Other_agency      0.471     0.427     0.448        75
#            Y      0.000     0.000     0.000         8
#
#     accuracy                          0.908      1218
#    macro avg      0.478     0.458     0.467      1218
# weighted avg      0.927     0.908     0.917      1218
#
# [[1074   34   27]
#  [  35   32    8]
#  [   6    2    0]]
#               precision    recall  f1-score   support
#
#     Employed      0.852     0.363     0.509       507
# Not_employed      1.000     0.039     0.076       331
# Work_at_Home      0.022     0.778     0.043        18
#
#     accuracy                          0.246       856
#    macro avg      0.625     0.393     0.209       856
# weighted avg      0.892     0.246     0.332       856
#
# [[184   0 323]
#  [ 28  13 290]
#  [  4   0  14]]
#                 precision    recall  f1-score   support
#
# General_Office      0.429     0.926     0.587       406
#  Manufacturing      0.265     0.103     0.149        87
#   Not_employed      1.000     0.272     0.428       437
# Retail&Service      0.271     0.088     0.133       147
#
#       accuracy                          0.480      1077
#      macro avg      0.491     0.348     0.324      1077
#   weighted avg      0.626     0.480     0.425      1077
#
# [[376  17   0  13]
#  [ 73   9   0   5]
#  [301   0 119  17]
#  [126   8   0  13]]
#                 precision    recall  f1-score   support
#
#              N      0.322     0.452     0.376       600
# Not Applicable      1.000     0.870     0.931      2453
#              Y      0.792     0.812     0.802      3031
#
#       accuracy                          0.800      6084
#      macro avg      0.705     0.711     0.703      6084
#   weighted avg      0.829     0.800     0.812      6084
#
# [[ 271    0  329]
#  [   0 2135  318]
#  [ 571    0 2460]]
#               precision    recall  f1-score   support
#
#  Not_student      0.854     1.000     0.921       700
#      Student      1.000     0.048     0.091       126
#
#     accuracy                          0.855       826
#    macro avg      0.927     0.524     0.506       826
# weighted avg      0.876     0.855     0.794       826
#
# [[700   0]
#  [120   6]]
#               precision    recall  f1-score   support
#
# (0.999, 2.0]      0.641     0.701     0.670       321
#   (2.0, 3.0]      0.118     0.026     0.042        78
#   (3.0, 4.0]      0.290     0.044     0.077       204
#   (4.0, 6.0]      0.275     0.083     0.128       132
#  (6.0, 18.0]      0.176     0.747     0.285        91
#
#     accuracy                          0.381       826
#    macro avg      0.300     0.320     0.240       826
# weighted avg      0.395     0.381     0.335       826
#
# [[225   7   7   8  74]
#  [ 23   2   3   5  45]
#  [ 69   2   9   9 115]
#  [ 24   4   8  11  85]
#  [ 10   2   4   7  68]]
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#    Apartment      0.000     0.000     0.000       119
#        House      0.748     1.000     0.856       618
#    Townhouse      0.000     0.000     0.000        89
#
#     accuracy                          0.748       826
#    macro avg      0.249     0.333     0.285       826
# weighted avg      0.560     0.748     0.640       826
#
# [[  0 119   0]
#  [  0 618   0]
#  [  0  89   0]]
#               precision    recall  f1-score   support
#
#    100k-124k      0.203     0.182     0.192      1671
#      15k-39k      0.310     0.529     0.391      2001
#      40k-59k      0.253     0.273     0.263      2122
#      60k-99k      0.363     0.172     0.233      3394
#         <15k      0.187     0.553     0.280       454
#        >124k      0.485     0.399     0.438      2839
#
#     accuracy                          0.313     12481
#    macro avg      0.300     0.351     0.300     12481
# weighted avg      0.336     0.313     0.306     12481
#
# [[ 304  244  250  313   89  471]
#  [  56 1059  316  135  396   39]
#  [ 140  836  580  175  237  154]
#  [ 429  847  734  583  268  533]
#  [   1  136   40   20  251    6]
#  [ 564  291  371  378  101 1134]]
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#  (0.99, 1.0]      0.000     0.000     0.000       106
#   (1.0, 2.0]      0.393     0.725     0.510       313
#   (2.0, 3.0]      0.278     0.035     0.062       143
#   (3.0, 4.0]      0.000     0.000     0.000       180
#   (4.0, 9.0]      0.087     0.238     0.127        84
#
#     accuracy                          0.305       826
#    macro avg      0.152     0.200     0.140       826
# weighted avg      0.206     0.305     0.217       826
#
# [[  0  77   5   0  24]
#  [  0 227   3   0  83]
#  [  0  92   5   0  46]
#  [  0 117   5   0  58]
#  [  0  64   0   0  20]]
#               precision    recall  f1-score   support
#
# (-0.01, 0.0]      0.000     0.000     0.000        22
#   (0.0, 1.0]      0.000     0.000     0.000       252
#   (1.0, 2.0]      0.000     0.000     0.000       401
#  (2.0, 99.0]      0.183     1.000     0.309       151
#
#     accuracy                          0.183       826
#    macro avg      0.046     0.250     0.077       826
# weighted avg      0.033     0.183     0.057       826
#
# [[  0   0   0  22]
#  [  0   0   0 252]
#  [  0   0   0 401]
#  [  0   0   0 151]]
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df_arr[-1].isnull().sum()
# Out:
# HBW               0
# HBD               0
# Non-HB            0
# Peak              0
# Off_peak          0
#                ...
# (3.0, 4.0]      826
# (2.0, 99.0]     826
# (0.0, 1.0]      826
# (1.0, 2.0]      826
# (-0.01, 0.0]    826
# Length: 73, dtype: int64

# %%
regress(df_arr[-1].copy(), index_array)
# Out:
# (34608, 17)
# (17223, 17)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                 precision    recall  f1-score   support
#
# (10.999, 19.0]      0.000     0.000     0.000        92
#   (19.0, 28.0]      0.000     0.000     0.000        77
#   (28.0, 35.0]      0.000     0.000     0.000        98
#   (35.0, 41.0]      0.000     0.000     0.000        86
#   (41.0, 47.0]      0.068     0.344     0.114        64
#   (47.0, 53.0]      0.084     0.575     0.146        73
#   (53.0, 58.0]      0.000     0.000     0.000        78
#   (58.0, 65.0]      0.000     0.000     0.000        96
#   (65.0, 72.0]      0.000     0.000     0.000        73
#   (72.0, 99.0]      0.000     0.000     0.000        89
#
#       accuracy                          0.077       826
#      macro avg      0.015     0.092     0.026       826
#   weighted avg      0.013     0.077     0.022       826
#
#               precision    recall  f1-score   support
#
#            F      0.593     0.120     0.200       424
#            M      0.496     0.913     0.643       402
#
#     accuracy                          0.506       826
#    macro avg      0.544     0.517     0.421       826
# weighted avg      0.546     0.506     0.415       826
#
#               precision    recall  f1-score   support
#
#            N      0.600     0.112     0.189       107
#            Y      0.907     0.991     0.947       931
#
#     accuracy                          0.901      1038
#    macro avg      0.753     0.552     0.568      1038
# weighted avg      0.875     0.901     0.869      1038
#
#               precision    recall  f1-score   support
#
#            N      0.962     0.941     0.951      1135
# Other_agency      0.408     0.413     0.411        75
#            Y      0.000     0.000     0.000         8
#
#     accuracy                          0.902      1218
#    macro avg      0.457     0.451     0.454      1218
# weighted avg      0.922     0.902     0.912      1218
#
#               precision    recall  f1-score   support
#
#     Employed      1.000     0.024     0.046       507
# Not_employed      1.000     0.039     0.076       331
# Work_at_Home      0.022     1.000     0.042        18
#
#     accuracy                          0.050       856
#    macro avg      0.674     0.354     0.055       856
# weighted avg      0.979     0.050     0.058       856
#
#                 precision    recall  f1-score   support
#
# General_Office      0.520     0.719     0.604       406
#  Manufacturing      0.268     0.126     0.172        87
#   Not_employed      1.000     0.272     0.428       437
# Retail&Service      0.177     0.429     0.250       147
#
#       accuracy                          0.450      1077
#      macro avg      0.491     0.387     0.364      1077
#   weighted avg      0.648     0.450     0.449      1077
#
#                 precision    recall  f1-score   support
#
#              N      0.261     0.647     0.372       600
# Not Applicable      1.000     0.870     0.931      2453
#              Y      0.790     0.641     0.708      3031
#
#       accuracy                          0.734      6084
#      macro avg      0.683     0.719     0.670      6084
#   weighted avg      0.822     0.734     0.764      6084
#
#               precision    recall  f1-score   support
#
#  Not_student      0.854     1.000     0.921       700
#      Student      1.000     0.048     0.091       126
#
#     accuracy                          0.855       826
#    macro avg      0.927     0.524     0.506       826
# weighted avg      0.876     0.855     0.794       826
#
#               precision    recall  f1-score   support
#
# (0.999, 2.0]      0.641     0.701     0.670       321
#   (2.0, 3.0]      0.118     0.026     0.042        78
#   (3.0, 4.0]      0.417     0.025     0.046       204
#   (4.0, 6.0]      0.275     0.083     0.128       132
#  (6.0, 18.0]      0.172     0.769     0.282        91
#
#     accuracy                          0.379       826
#    macro avg      0.325     0.321     0.234       826
# weighted avg      0.426     0.379     0.327       826
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#    Apartment      0.000     0.000     0.000       119
#        House      0.748     1.000     0.856       618
#    Townhouse      0.000     0.000     0.000        89
#
#     accuracy                          0.748       826
#    macro avg      0.249     0.333     0.285       826
# weighted avg      0.560     0.748     0.640       826
#
#               precision    recall  f1-score   support
#
#    100k-124k      0.206     0.218     0.212      1671
#      15k-39k      0.300     0.418     0.349      2001
#      40k-59k      0.247     0.289     0.267      2122
#      60k-99k      0.365     0.178     0.240      3394
#         <15k      0.178     0.685     0.282       454
#        >124k      0.495     0.355     0.414      2839
#
#     accuracy                          0.300     12481
#    macro avg      0.299     0.357     0.294     12481
# weighted avg      0.336     0.300     0.299     12481
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#  (0.99, 1.0]      0.000     0.000     0.000       106
#   (1.0, 2.0]      0.333     0.089     0.141       313
#   (2.0, 3.0]      0.122     0.035     0.054       143
#   (3.0, 4.0]      0.000     0.000     0.000       180
#   (4.0, 9.0]      0.096     0.798     0.171        84
#
#     accuracy                          0.121       826
#    macro avg      0.110     0.184     0.073       826
# weighted avg      0.157     0.121     0.080       826
#
#               precision    recall  f1-score   support
#
# (-0.01, 0.0]      0.000     0.000     0.000        22
#   (0.0, 1.0]      0.000     0.000     0.000       252
#   (1.0, 2.0]      0.000     0.000     0.000       401
#  (2.0, 99.0]      0.183     1.000     0.309       151
#
#     accuracy                          0.183       826
#    macro avg      0.046     0.250     0.077       826
# weighted avg      0.033     0.183     0.057       826
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#correct A predictions out of all the A predictions
precision_score(y_test, y_predict, average = None)
# Out:
# array([0.77454545, 0.45502646, 0.2195122 , 0.34636872, 0.24285714,
#        0.16935484, 0.20689655, 0.24      , 0.31196581, 0.5528169 ])

# %%
regress(df_arr[-1].copy(), index_array)
# Out:
# (34608, 17)
# (17223, 17)
#                 precision    recall  f1-score   support
#
# (10.999, 19.0]      0.833     0.867     0.850      2264
#   (19.0, 28.0]      0.451     0.381     0.413      1641
#   (28.0, 35.0]      0.256     0.183     0.213      1795
#   (35.0, 41.0]      0.296     0.418     0.347      1454
#   (41.0, 47.0]      0.244     0.113     0.154      1430
#   (47.0, 53.0]      0.174     0.246     0.204      1445
#   (53.0, 58.0]      0.231     0.167     0.194      1374
#   (58.0, 65.0]      0.217     0.209     0.213      1953
#   (65.0, 72.0]      0.306     0.451     0.365      1811
#   (72.0, 99.0]      0.524     0.485     0.503      2218
#
#       accuracy                          0.378     17385
#      macro avg      0.353     0.352     0.346     17385
#   weighted avg      0.378     0.378     0.372     17385
#
#               precision    recall  f1-score   support
#
#            F      0.627     0.613     0.620      9440
#            M      0.552     0.566     0.559      7945
#
#     accuracy                          0.592     17385
#    macro avg      0.589     0.590     0.589     17385
# weighted avg      0.593     0.592     0.592     17385
#
#               precision    recall  f1-score   support
#
#            N      0.753     0.783     0.768      2379
#            Y      0.965     0.959     0.962     15006
#
#     accuracy                          0.935     17385
#    macro avg      0.859     0.871     0.865     17385
# weighted avg      0.936     0.935     0.936     17385
#
#               precision    recall  f1-score   support
#
#            N      0.934     0.994     0.963     15811
# Other_agency      0.745     0.269     0.395      1459
#            Y      0.211     0.035     0.060       115
#
#     accuracy                          0.927     17385
#    macro avg      0.630     0.433     0.473     17385
# weighted avg      0.913     0.927     0.909     17385
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#     Employed      0.978     0.889     0.931      8024
# Not_employed      0.908     1.000     0.952      9165
# Work_at_Home      0.000     0.000     0.000       196
#
#     accuracy                          0.937     17385
#    macro avg      0.629     0.630     0.628     17385
# weighted avg      0.930     0.937     0.932     17385
#
#                 precision    recall  f1-score   support
#
# General_Office      0.663     0.904     0.765      5055
#  Manufacturing      0.212     0.072     0.108       899
#   Not_employed      0.941     1.000     0.970      9165
# Retail&Service      0.855     0.171     0.285      2266
#
#       accuracy                          0.816     17385
#      macro avg      0.668     0.537     0.532     17385
#   weighted avg      0.811     0.816     0.776     17385
#
#                 precision    recall  f1-score   support
#
#              N      0.574     0.154     0.242      1420
# Not Applicable      0.947     1.000     0.973      9165
#              Y      0.845     0.910     0.877      6800
#
#       accuracy                          0.896     17385
#      macro avg      0.788     0.688     0.697     17385
#   weighted avg      0.876     0.896     0.875     17385
#
#               precision    recall  f1-score   support
#
#  Not_student      0.951     0.985     0.968     14060
#      Student      0.927     0.784     0.850      3325
#
#     accuracy                          0.947     17385
#    macro avg      0.939     0.885     0.909     17385
# weighted avg      0.946     0.947     0.945     17385
#
#               precision    recall  f1-score   support
#
# (0.999, 2.0]      0.537     0.853     0.659      5798
#   (2.0, 3.0]      0.369     0.042     0.075      1879
#   (3.0, 4.0]      0.366     0.213     0.269      4072
#   (4.0, 6.0]      0.285     0.298     0.291      3239
#  (6.0, 18.0]      0.332     0.305     0.318      2397
#
#     accuracy                          0.436     17385
#    macro avg      0.378     0.342     0.323     17385
# weighted avg      0.403     0.436     0.389     17385
#
#               precision    recall  f1-score   support
#
#    Apartment      0.621     0.191     0.292      2768
#        House      0.767     0.984     0.862     12886
#    Townhouse      0.000     0.000     0.000      1731
#
#     accuracy                          0.760     17385
#    macro avg      0.463     0.392     0.385     17385
# weighted avg      0.667     0.760     0.685     17385
#
#               precision    recall  f1-score   support
#
#    100k-124k      0.214     0.032     0.056      2220
#      15k-39k      0.425     0.474     0.448      2572
#      40k-59k      0.300     0.146     0.196      2776
#      60k-99k      0.317     0.612     0.418      4448
#         <15k      0.592     0.237     0.339       611
#        >124k      0.552     0.465     0.505      4758
#
#     accuracy                          0.390     17385
#    macro avg      0.400     0.328     0.327     17385
# weighted avg      0.391     0.390     0.362     17385
#
#               precision    recall  f1-score   support
#
#  (0.99, 1.0]      0.618     0.226     0.331      2345
#   (1.0, 2.0]      0.573     0.816     0.673      6470
#   (2.0, 3.0]      0.360     0.129     0.189      3042
#   (3.0, 4.0]      0.406     0.680     0.509      3493
#   (4.0, 9.0]      0.511     0.095     0.160      2035
#
#     accuracy                          0.504     17385
#    macro avg      0.494     0.389     0.372     17385
# weighted avg      0.501     0.504     0.449     17385
#
#               precision    recall  f1-score   support
#
# (-0.01, 0.0]      0.783     0.435     0.560       620
#   (0.0, 1.0]      0.787     0.425     0.552      5716
#   (1.0, 2.0]      0.594     0.825     0.691      8137
#  (2.0, 99.0]      0.459     0.419     0.438      2912
#
#     accuracy                          0.611     17385
#    macro avg      0.656     0.526     0.560     17385
# weighted avg      0.642     0.611     0.598     17385

# %%
# correct A prediction out of total true A predictions from the test set
recall_score(y_test, y_predict, average = None)
# Out:
# array([0.87295082, 0.43434343, 0.19014085, 0.5       , 0.14655172,
#        0.1640625 , 0.1       , 0.27979275, 0.34761905, 0.54895105])

# %%
df_arr = pd.read_pickle('df_prop_arr')
df = df_arr[0]
df_0 = pd.read_feather('df_0')
df_50 = pd.read_feather('df_-1')
missing_columns = [x for x in df.columns if df[x].isnull().sum().sum() != 0]

# %%
def mean_imp(df_not_dummy):
    df_freq = df_not_dummy.applymap(str)
    mean_imputer = SimpleImputer(strategy='most_frequent', missing_values='None') # imputing using constant value
    nd = mean_imputer.fit_transform(df_freq)
    return nd
